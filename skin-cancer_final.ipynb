# %%
import os
import zipfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as p
import PIL as pil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import seaborn as sns
import wget

# %%
wget.download("https://storage.googleapis.com/kagglesdsdata/datasets/54339/104884/HAM10000_metadata.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220730%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220730T074243Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...", out="Data")
# Out:
# 'HAM10000_metadata.csv'

# %%
filename = wget.download("https://storage.googleapis.com/kaggle-data-sets/54339/104884/compressed/hmnist_28_28_RGB.csv.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220730%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220730T064808Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
with zipfile.ZipFile(filename,"r") as zip_ref:
    zip_ref.extractall("Data")

# %%
meta=pd.read_csv('./Data/HAM10000_metadata.csv')
meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lesion_id     10015 non-null  object
#  1   image_id      10015 non-null  object
#  2   dx            10015 non-null  object
#  3   dx_type       10015 non-null  object
#  4   age           9958 non-null   float64
#  5   sex           10015 non-null  object
#  6   localization  10015 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 547.8+ KB

# %% [markdown]
# # **Visualising Dataset**

# %%
meta.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
g = sns.catplot(x="dx", kind="count", palette='bright', data=meta)
g.fig.set_size_inches(16, 5)

g.ax.set_title('Skin Cancer by Class', fontsize=20)
g.set_xlabels('Skin Cancer Class', fontsize=14)
g.set_ylabels('Number of Data Points', fontsize=14)
p.savefig('./Visualization/skin_cancer_by_class.png')

# %% [markdown]
# This graph shows the dataset has a major problem of class imbalance.

# %%
g = sns.catplot(x="dx", kind="count", hue="sex", palette='coolwarm', data=meta)
g.fig.set_size_inches(16, 5)

g.ax.set_title('Skin Cancer by Sex', fontsize=20)
g.set_xlabels('Skin Cancer Class', fontsize=14)
g.set_ylabels('Number of Data Points', fontsize=14)
g._legend.set_title('Sex')
p.savefig("./Visualization/skin_cancer_by_sex.png")

# %%
g = sns.catplot(x="dx", kind="count", hue="age", palette='bright', data=meta)
g.fig.set_size_inches(16, 9)

g.ax.set_title('Skin Cancer by Age', fontsize=20)
g.set_xlabels('Skin Cancer Class', fontsize=14)
g.set_ylabels('Number of Data Points', fontsize=14)
g._legend.set_title('Age')
p.savefig("./Visualization/skin_cancer_by_age.png")

# %% [markdown]
# # **Extracting x and y from csv file**

# %%
df=pd.read_csv('./Data/hmnist_28_28_RGB.csv')
x=df.drop('label',axis=1)
y=df['label']
x=x.to_numpy()
x=x/255
y=to_categorical(y)

# %%
df['label'].value_counts()
# Out:
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: label, dtype: int64

# %%
label={
    ' Actinic keratoses':0,
    'Basal cell carcinoma':1,
    'Benign keratosis-like lesions':2,
    'Dermatofibroma':3,
    'Melanocytic nevi':4,
    'Melanoma':6,
    'Vascular lesions':5
}

# %%
x=x.reshape(-1,28,28,3)

# %% [markdown]
# # **Sample images**

# %%
p.figure(figsize=(20,10))
for i in range(25):
    p.subplot(5,5,i+1)
    img=x[i]
    p.imshow(img)

p.savefig("./Visualization/data_to_image.png")

# %% [markdown]
# # **Spliiting into train test**

# %%
trainx,trainy,testx,testy = train_test_split(x,y,test_size=0.02,random_state=13)

# %%
print(len(trainx))
print(len(testy))
# Out:
# 9814
# 201

# %% [markdown]
# # **Image augmentation**

# %%
datagen=ImageDataGenerator(rotation_range=20, # rotate the image 20 degrees
                               width_shift_range=0.10, # Shift the pic width by a max of 5%
                               height_shift_range=0.10, # Shift the pic height by a max of 5%
                               rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.1, # Shear means cutting away part of the image (max 10%)
                               zoom_range=0.1, # Zoom in by 10% max
                               horizontal_flip=True,
                               vertical_flip=True,
                               fill_mode='nearest')
datagen1=ImageDataGenerator(rotation_range=20, # rotate the image 20 degrees
                               width_shift_range=0.10, # Shift the pic width by a max of 5%
                               height_shift_range=0.10, # Shift the pic height by a max of 5%
                               rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.1, # Shear means cutting away part of the image (max 10%)
                               zoom_range=0.1, # Zoom in by 10% max
                               horizontal_flip=True,
                               vertical_flip=True,
                               fill_mode='nearest')

# %%
datagen.fit(trainx)
datagen1.fit(trainy)

# %% [markdown]
# # **Model**

# %%
from tensorflow.keras.layers import Flatten,Dense,Dropout,BatchNormalization,Conv2D,MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import Recall
from tensorflow.keras.optimizers import RMSprop

model=Sequential()

model.add(Conv2D(64,(2,2),input_shape=(28,28,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(512,(2,2),input_shape=(28,28,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Dropout(0.3))

model.add(Conv2D(1024,(2,2),input_shape=(28,28,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Dropout(0.4))

model.add(Conv2D(1024,(1,1),input_shape=(28,28,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(1, 1)))
model.add(BatchNormalization())

model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(256,activation='relu'))
model.add(Dropout(0.5))


model.add(Dense(7,activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy',Recall()])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 27, 27, 64)        832
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  batch_normalization (BatchN  (None, 13, 13, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 512)       131584
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 512)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 6, 6, 512)        2048
#  hNormalization)
#
#  dropout (Dropout)           (None, 6, 6, 512)         0
#
#  conv2d_2 (Conv2D)           (None, 5, 5, 1024)        2098176
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 1024)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 2, 2, 1024)       4096
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 2, 2, 1024)        0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 1024)        1049600
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 1024)       0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 2, 2, 1024)       4096
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 2, 2, 1024)        0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 256)               1048832
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 4,341,319
# Trainable params: 4,336,071
# Non-trainable params: 5,248
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau

early=EarlyStopping(monitor='accuracy',patience=3)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1, mode='min', min_lr=0.0001)

# %%
model.fit(trainx,testx,batch_size=90,epochs=25,validation_data=(trainy,testy),callbacks=[reduce_lr,early])
# Out:
# Epoch 1/25
# 110/110 [==============================] - 143s 1s/step - loss: 1.2133 - accuracy: 0.6455 - recall: 0.5709 - val_loss: 2.5898 - val_accuracy: 0.0498 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 2/25
# 110/110 [==============================] - 122s 1s/step - loss: 0.8709 - accuracy: 0.6941 - recall: 0.5934 - val_loss: 2.1516 - val_accuracy: 0.1095 - val_recall: 0.1045 - lr: 0.0010
# Epoch 3/25
# 110/110 [==============================] - 123s 1s/step - loss: 0.7830 - accuracy: 0.7184 - recall: 0.6138 - val_loss: 2.5239 - val_accuracy: 0.0249 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 4/25
# 110/110 [==============================] - 123s 1s/step - loss: 0.7445 - accuracy: 0.7278 - recall: 0.6266 - val_loss: 1.9585 - val_accuracy: 0.1095 - val_recall: 0.0896 - lr: 0.0010
# Epoch 5/25
# 110/110 [==============================] - 125s 1s/step - loss: 0.7253 - accuracy: 0.7326 - recall: 0.6440 - val_loss: 1.1399 - val_accuracy: 0.5821 - val_recall: 0.2836 - lr: 0.0010
# Epoch 6/25
# 110/110 [==============================] - 132s 1s/step - loss: 0.7188 - accuracy: 0.7351 - recall: 0.6407 - val_loss: 0.9114 - val_accuracy: 0.6816 - val_recall: 0.4328 - lr: 0.0010
# Epoch 7/25
# 110/110 [==============================] - 124s 1s/step - loss: 0.6935 - accuracy: 0.7422 - recall: 0.6548 - val_loss: 0.8700 - val_accuracy: 0.6667 - val_recall: 0.5075 - lr: 0.0010
# Epoch 8/25
# 110/110 [==============================] - 130s 1s/step - loss: 0.6827 - accuracy: 0.7450 - recall: 0.6583 - val_loss: 0.6980 - val_accuracy: 0.7612 - val_recall: 0.7463 - lr: 0.0010
# Epoch 9/25
# 110/110 [==============================] - 141s 1s/step - loss: 0.6783 - accuracy: 0.7503 - recall: 0.6689 - val_loss: 0.5667 - val_accuracy: 0.7512 - val_recall: 0.6617 - lr: 0.0010
# Epoch 10/25
# 110/110 [==============================] - 131s 1s/step - loss: 0.6662 - accuracy: 0.7534 - recall: 0.6712 - val_loss: 0.6823 - val_accuracy: 0.7662 - val_recall: 0.7463 - lr: 0.0010
# Epoch 11/25
# 110/110 [==============================] - ETA: 0s - loss: 0.6591 - accuracy: 0.7540 - recall: 0.6733
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 110/110 [==============================] - 140s 1s/step - loss: 0.6591 - accuracy: 0.7540 - recall: 0.6733 - val_loss: 1.3083 - val_accuracy: 0.4129 - val_recall: 0.3085 - lr: 0.0010
# Epoch 12/25
# 110/110 [==============================] - 161s 1s/step - loss: 0.6375 - accuracy: 0.7660 - recall: 0.6880 - val_loss: 0.5407 - val_accuracy: 0.8060 - val_recall: 0.7711 - lr: 5.0000e-04
# Epoch 13/25
# 110/110 [==============================] - 162s 1s/step - loss: 0.5857 - accuracy: 0.7842 - recall: 0.7127 - val_loss: 0.5439 - val_accuracy: 0.7761 - val_recall: 0.7065 - lr: 5.0000e-04
# Epoch 14/25
# 110/110 [==============================] - ETA: 0s - loss: 0.5753 - accuracy: 0.7841 - recall: 0.7174
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 110/110 [==============================] - 160s 1s/step - loss: 0.5753 - accuracy: 0.7841 - recall: 0.7174 - val_loss: 0.5743 - val_accuracy: 0.7761 - val_recall: 0.6716 - lr: 5.0000e-04
# Epoch 15/25
# 110/110 [==============================] - 136s 1s/step - loss: 0.5475 - accuracy: 0.7941 - recall: 0.7265 - val_loss: 0.5416 - val_accuracy: 0.8159 - val_recall: 0.7363 - lr: 2.5000e-04
# Epoch 16/25
# 110/110 [==============================] - ETA: 0s - loss: 0.5278 - accuracy: 0.8013 - recall: 0.7370
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 110/110 [==============================] - 124s 1s/step - loss: 0.5278 - accuracy: 0.8013 - recall: 0.7370 - val_loss: 0.5407 - val_accuracy: 0.8109 - val_recall: 0.7164 - lr: 2.5000e-04
# Epoch 17/25
# 110/110 [==============================] - 115s 1s/step - loss: 0.5141 - accuracy: 0.8061 - recall: 0.7417 - val_loss: 0.4740 - val_accuracy: 0.8159 - val_recall: 0.7512 - lr: 1.2500e-04
# Epoch 18/25
# 110/110 [==============================] - 116s 1s/step - loss: 0.4930 - accuracy: 0.8099 - recall: 0.7559 - val_loss: 0.6297 - val_accuracy: 0.7512 - val_recall: 0.6766 - lr: 1.2500e-04
# Epoch 19/25
# 110/110 [==============================] - ETA: 0s - loss: 0.5034 - accuracy: 0.8100 - recall: 0.7540
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001.
# 110/110 [==============================] - 125s 1s/step - loss: 0.5034 - accuracy: 0.8100 - recall: 0.7540 - val_loss: 0.4992 - val_accuracy: 0.8159 - val_recall: 0.7861 - lr: 1.2500e-04
# Epoch 20/25
# 110/110 [==============================] - 115s 1s/step - loss: 0.4781 - accuracy: 0.8169 - recall: 0.7665 - val_loss: 0.4671 - val_accuracy: 0.8259 - val_recall: 0.7562 - lr: 1.0000e-04
# Epoch 21/25
# 110/110 [==============================] - 115s 1s/step - loss: 0.4685 - accuracy: 0.8205 - recall: 0.7716 - val_loss: 0.4729 - val_accuracy: 0.8308 - val_recall: 0.7711 - lr: 1.0000e-04
# Epoch 22/25
# 110/110 [==============================] - 115s 1s/step - loss: 0.4648 - accuracy: 0.8214 - recall: 0.7740 - val_loss: 0.4788 - val_accuracy: 0.8209 - val_recall: 0.7811 - lr: 1.0000e-04
# Epoch 23/25
# 110/110 [==============================] - 116s 1s/step - loss: 0.4520 - accuracy: 0.8276 - recall: 0.7799 - val_loss: 0.4621 - val_accuracy: 0.8209 - val_recall: 0.7761 - lr: 1.0000e-04
# Epoch 24/25
# 110/110 [==============================] - 125s 1s/step - loss: 0.4489 - accuracy: 0.8296 - recall: 0.7809 - val_loss: 0.4721 - val_accuracy: 0.8259 - val_recall: 0.7960 - lr: 1.0000e-04
# Epoch 25/25
# 110/110 [==============================] - 115s 1s/step - loss: 0.4383 - accuracy: 0.8296 - recall: 0.7855 - val_loss: 0.4768 - val_accuracy: 0.8159 - val_recall: 0.7711 - lr: 1.0000e-04

# %%
p.figure(figsize=(15,5))
loss=pd.DataFrame(model.history.history)
loss=loss[['accuracy','val_accuracy']]
loss.plot()

p.savefig("./Visualization/evaluation_metrics.png")
